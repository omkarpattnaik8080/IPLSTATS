# %% [markdown]
# <a href="https://colab.research.google.com/github/omkarpattnaik8080/IPLSTATS/blob/main/IPLstats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url_players=pd.read_html("https://www.iplt20.com/stats/2023")

# %%
type(url_players)
# Out:
# list

# %%
#no of tables inside a list
len(url_players)
# Out:
# 1

# %%
df3=url_players[0]

# %%
df3
# Out:
#                                                    0  \
# 0                                               Role
# 1                                               Bats
# 2                                                NaN
# 3                                                Bio
# 4  A 22-year old opening batsman who hails from P...
#
#                                                    1  \
# 0                                            Batsman
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  A 22-year old opening batsman who hails from P...
#
#                                                    2  \
# 0                                        Nationality
# 1                                              Bowls
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df3.head()
# Out:
#                                                    0  \
# 0                                               Role
# 1                                               Bats
# 2                                                NaN
# 3                                                Bio
# 4  A 22-year old opening batsman who hails from P...
#
#                                                    1  \
# 0                                            Batsman
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  A 22-year old opening batsman who hails from P...
#
#                                                    2  \
# 0                                        Nationality
# 1                                              Bowls
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df3.tail()
# Out:
#                                                    0  \
# 0                                               Role
# 1                                               Bats
# 2                                                NaN
# 3                                                Bio
# 4  A 22-year old opening batsman who hails from P...
#
#                                                    1  \
# 0                                            Batsman
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  A 22-year old opening batsman who hails from P...
#
#                                                    2  \
# 0                                        Nationality
# 1                                              Bowls
# 2                                                NaN
# 3                                                NaN
# ...

# %%
df3.columns
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
#agar sare columns ke datatypes apko dekhna hai
df3.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4    float64
# dtype: object

# %%
#data ko store bhi kiya ja sakta hai in some file system
df3.to_csv("players_data.csv")
